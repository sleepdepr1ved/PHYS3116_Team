# %% [markdown]
# ## Meeting Minutes

# %% [markdown]
# **Friday 26/9/25** (lecture break)
#
# *Attendance: Everyone*
#
# - Create the GitHub repositry and add everyone
# - Everyone start looking at the data to get an idea of what we're working with and the best way to go about it
# - Maybe each person focus on a different data set and see what we find

# %% [markdown]
# **Friday 3/10/25** (lecture break)
#
# *Attendance: Everyone*
#
# - Decided longer meetings would be better
# - Meeting time changed to Fridays 2-3pm (at OMB ground floor hot desks?)
# - Everyone looked at the data and made some plots (which will be added to GitHub)

# %% [markdown]
# **Friday 10/10/25** 1pm-2pm
#
# *Attendance: Everyone*
#
# - Shared and discussed academic papers relevant to the the data that we're analysing.
# - Decided what each person will focus on over the next week.
#     - Combining all data sets for the age metallicity plot
#     - Looking the rotation of the GCs and determining outliers
#     - Exploring more of the relations of the dynamical properties of the data
# - Start writing analysis for the plots that we've made.
