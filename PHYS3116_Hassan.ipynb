# %% [markdown]
# Moving code to ipynb type and updating it

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Display plots inline in VS Code notebook view
plt.rcParams['figure.figsize'] = (8,6)
plt.rcParams['axes.grid'] = True
